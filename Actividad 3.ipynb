# %%
from sklearn.datasets import make_blobs

# %%
X , y = make_blobs(n_samples=400, centers=5, cluster_std=0.6, random_state=0)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(X[:,0], X[:,1])

# %%
from sklearn.cluster import KMeans
from sklearn import datasets

# %%
# Creamos el estimador y lo entrenamos. 

est2 = KMeans(n_clusters = 2)
est2.fit(X)
est3 = KMeans(n_clusters = 3)
est3.fit(X)
est4 = KMeans(n_clusters = 4)
est4.fit(X)
est5 = KMeans(n_clusters = 5)
est5.fit(X)
est6 = KMeans(n_clusters = 6)
est6.fit(X)
est7 = KMeans(n_clusters = 7)
est7.fit(X)
est8 = KMeans(n_clusters = 8)
est8.fit(X)
est9 = KMeans(n_clusters = 9)
est9.fit(X)
est10 = KMeans(n_clusters = 10)
est10.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
print(X)
print("------------")
print(est2.labels_)
print("------------")
print(est3.labels_)
print("------------")
print(est4.labels_)
print("-------------")
print(est5.labels_)
print("------------")
print(est6.labels_)
print("------------")
print(est7.labels_)
print("------------")
print(est8.labels_)
print("------------")
print(est9.labels_)
print("------------")
print(est10.labels_)
# Out:
# [[ -5.19811282e+00   6.41869316e-01]
#  [ -5.75229538e+00   4.18627111e-01]
#  [ -1.08448984e+01  -7.55352273e+00]
#  ...,
#  [  1.36105255e+00  -9.07491863e-01]
#  [ -3.54141108e-01   7.12241630e-01]
#  [  1.88577252e+00   1.41185693e-03]]
# ------------
# [1 1 0 ..., 1 1 1]
# ------------
# [1 1 0 ..., 2 2 2]
# ------------
# [2 2 3 ..., 0 0 0]
# -------------
# [4 4 1 ..., 2 2 2]
# ------------
# [0 0 5 ..., 2 4 2]
# ------------
# [6 6 4 ..., 3 5 3]
# ------------
# [2 2 7 ..., 6 3 6]
# ------------
# [2 2 8 ..., 4 4 4]
# ------------
# [2 2 4 ..., 7 5 7]

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 12))

# 2 clusters
est2_p=est2.fit_predict(X)
plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=est2_p)
plt.title("Clusters: 2")

# 3 clusters
est3_p=est3.fit_predict(X)
plt.subplot(222)
plt.scatter(X[:, 0], X[:, 1], c=est3_p)
plt.title("Clusters: 3")

# 4 clusters
est4_p=est4.fit_predict(X)
plt.subplot(223)
plt.scatter(X[:, 0], X[:, 1], c=est4_p)
plt.title("Clusters: 4")

# 5 clusters
est5_p=est5.fit_predict(X)
plt.subplot(224)
plt.scatter(X[:, 0], X[:, 1], c=est5_p)
plt.title("Clusters: 5")

plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
plt.figure(figsize=(12, 12))

# 6 clusters
est6_p=est6.fit_predict(X)
plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=est6_p)
plt.title("Clusters: 6")

# 7 clusters
est7_p=est7.fit_predict(X)
plt.subplot(222)
plt.scatter(X[:, 0], X[:, 1], c=est7_p)
plt.title("Clusters: 7")

# 8 clusters
est8_p=est8.fit_predict(X)
plt.subplot(223)
plt.scatter(X[:, 0], X[:, 1], c=est8_p)
plt.title("Clusters: 8")

# 9 clusters
est9_p=est9.fit_predict(X)
plt.subplot(224)
plt.scatter(X[:, 0], X[:, 1], c=est9_p)
plt.title("Clusters: 9")

plt.show()

# %%
from sklearn import metrics
print("Para 2 clusters, el score es:", metrics.silhouette_score(X, est2.labels_, metric='euclidean'))
print("Para 3 clusters, el score es:",metrics.silhouette_score(X, est3.labels_, metric='euclidean'))
print("Para 4 clusters, el score es:",metrics.silhouette_score(X, est4.labels_, metric='euclidean'))
print("Para 5 clusters, el score es:",metrics.silhouette_score(X, est5.labels_, metric='euclidean'))
print("Para 6 clusters, el score es:",metrics.silhouette_score(X, est6.labels_, metric='euclidean'))
print("Para 7 clusters, el score es:",metrics.silhouette_score(X, est7.labels_, metric='euclidean'))
print("Para 8 clusters, el score es:",metrics.silhouette_score(X, est8.labels_, metric='euclidean'))
print("Para 9 clusters, el score es:",metrics.silhouette_score(X, est9.labels_, metric='euclidean'))
print("Para 10 clusters, el score es:",metrics.silhouette_score(X, est10.labels_, metric='euclidean'))
# Out:
# Para 2 clusters, el score es: 0.627737523771
# Para 3 clusters, el score es: 0.733342348626
# Para 4 clusters, el score es: 0.586825352911
# Para 5 clusters, el score es: 0.441488983682
# Para 6 clusters, el score es: 0.306520461542
# Para 7 clusters, el score es: 0.324443194072
# Para 8 clusters, el score es: 0.327721213476
# Para 9 clusters, el score es: 0.32053109718
# Para 10 clusters, el score es: 0.336102027864

# %% [markdown]
# PREGUNTA 2

# %%
dataset =  [['Audifonos', 'Pilas'], 
            ['Afeitadora', 'USB', 'Router','Mouse'], 
            ['Laptop','USB','Antivirus','Mouse'], 
            ['Laptop','USB','Mouse'], 
            ['Mouse','Laptop','USB','Mouse'],
            ['Mouse','Audifonos','USB','Mouse'],
            ['Carcasa celular','Protector de pantalla'],
            ['Protector de pantalla','USB','Carcasa celular'],
            ['Audifonos','USB','Cargador','Mouse'],
            ['Celular','Cargador'],
            ['USB','Cargador']]

# %%
##import apriori
print(dataset)
# Out:
# [['Audifonos', 'Pilas'], ['Afeitadora', 'USB', 'Router', 'Mouse'], ['Laptop', 'USB', 'Antivirus', 'Mouse'], ['Laptop', 'USB', 'Mouse'], ['Mouse', 'Laptop', 'USB', 'Mouse'], ['Mouse', 'Audifonos', 'USB', 'Mouse'], ['Carcasa celular', 'Protector de pantalla'], ['Protector de pantalla', 'USB', 'Carcasa celular'], ['Audifonos', 'USB', 'Cargador', 'Mouse'], ['Celular', 'Cargador'], ['USB', 'Cargador']]

# %%
import apriori
F, soporte = apriori.apriori(dataset, min_support=0.4, verbose=True)
# Out:
# {USB}:  sup = 0.727
# {Mouse}:  sup = 0.545
# {USB, Mouse}:  sup = 0.545

# %%
# Generamos las reglas de asociación de la lista de itemsets frecuentes
# En este caso, se filtran las que no llegan a una confianza determinada.
H = apriori.generate_rules(F, soporte, min_confidence=0.9, verbose=True)
# Out:
# {Mouse} ---> {USB}:  conf = 1.0, sup = 0.545

# %%
H2 = apriori.generate_rules(F, soporte, min_confidence=0.2, verbose=True)
# Out:
# {Mouse} ---> {USB}:  conf = 1.0, sup = 0.545
# {USB} ---> {Mouse}:  conf = 0.75, sup = 0.545

# %% [markdown]
# Comprendiendo el algoritmo

# %%
# Generación de los 1-itemsets.
C1 = apriori.create_candidates(dataset, verbose=True)
# Out:
# {Afeitadora, Antivirus, Audifonos, Carcasa celular, Cargador, Celular, Laptop, Mouse, Pilas, Protector de pantalla, Router, USB}

# %%
# La idea es eliminar de los 1-itemsets los que no lleguen al soporte establecido.
# Esto reduce las combinaciones que hay que examinar en los siguientes pasos.
# Como el soporte que pedimos es 60% vemos que se elimina "Coke" y "Eggs".
# Por ejemplo "Eggs" solo aparece en 1/5, es decir, un 20% de las transacciones.
# Este es un paso de "poda" (prune) de los candidatos.

ftemp, stemp = apriori.support_prune(dataset, C1, 0.6)
print("1-itemsets frecuentes:", ftemp)
print("-----")
print("Soporte de los 1-itemsets:", stemp)
# Out:
# 1-itemsets frecuentes: [frozenset({'USB'})]
# -----
# Soporte de los 1-itemsets: {frozenset({'Audifonos'}): 0.2727272727272727, frozenset({'Pilas'}): 0.09090909090909091, frozenset({'Afeitadora'}): 0.09090909090909091, frozenset({'Mouse'}): 0.5454545454545454, frozenset({'Router'}): 0.09090909090909091, frozenset({'USB'}): 0.7272727272727273, frozenset({'Antivirus'}): 0.09090909090909091, frozenset({'Laptop'}): 0.2727272727272727, frozenset({'Carcasa celular'}): 0.18181818181818182, frozenset({'Protector de pantalla'}): 0.18181818181818182, frozenset({'Cargador'}): 0.2727272727272727, frozenset({'Celular'}): 0.09090909090909091}

# %% [markdown]
# Pregunta 3

# %%
print(__doc__)

import time
import warnings

import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

np.random.seed(0)

# ============
# Generate datasets. We choose the size big enough to see the scalability
# of the algorithms, but not too big to avoid too long running times
# ============
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,
                                      noise=.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), None

# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# blobs with varied variances
varied = datasets.make_blobs(n_samples=n_samples,
                             cluster_std=[1.0, 2.5, 0.5],
                             random_state=random_state)

# ============
# Set up cluster parameters
# ============
plt.figure(figsize=(9 * 2 + 3, 12.5))
plt.subplots_adjust(left=.02, right=.98, bottom=.001, top=.96, wspace=.05,
                    hspace=.01)

plot_num = 1

default_base = {'quantile': .3,
                'eps': .3,
                'damping': .9,
                'preference': -200,
                'n_neighbors': 10,
                'n_clusters': 3}

datasets = [
    (noisy_circles, {'damping': .77, 'preference': -240,
                     'quantile': .2, 'n_clusters': 2}),
    (noisy_moons, {'damping': .75, 'preference': -220, 'n_clusters': 2}),
    (varied, {'eps': .18, 'n_neighbors': 2}),
    (aniso, {'eps': .15, 'n_neighbors': 2}),
    (blobs, {}),
    (no_structure, {})]

for i_dataset, (dataset, algo_params) in enumerate(datasets):
    # update parameters with dataset-specific values
    params = default_base.copy()
    params.update(algo_params)

    X, y = dataset

    # normalize dataset for easier parameter selection
    X = StandardScaler().fit_transform(X)

    # estimate bandwidth for mean shift
    bandwidth = cluster.estimate_bandwidth(X, quantile=params['quantile'])

    # connectivity matrix for structured Ward
    connectivity = kneighbors_graph(
        X, n_neighbors=params['n_neighbors'], include_self=False)
    # make connectivity symmetric
    connectivity = 0.5 * (connectivity + connectivity.T)

    # ============
    # Create cluster objects
    # ============
    ms = cluster.MeanShift(bandwidth=bandwidth, bin_seeding=True)
    two_means = cluster.MiniBatchKMeans(n_clusters=params['n_clusters'])
    ward = cluster.AgglomerativeClustering(
        n_clusters=params['n_clusters'], linkage='ward',
        connectivity=connectivity)
    spectral = cluster.SpectralClustering(
        n_clusters=params['n_clusters'], eigen_solver='arpack',
        affinity="nearest_neighbors")
    dbscan = cluster.DBSCAN(eps=params['eps'])
    affinity_propagation = cluster.AffinityPropagation(
        damping=params['damping'], preference=params['preference'])
    average_linkage = cluster.AgglomerativeClustering(
        linkage="average", affinity="cityblock",
        n_clusters=params['n_clusters'], connectivity=connectivity)
    birch = cluster.Birch(n_clusters=params['n_clusters'])
    gmm = mixture.GaussianMixture(
        n_components=params['n_clusters'], covariance_type='full')

    clustering_algorithms = (
        ('MiniBatchKMeans', two_means),
        ('AffinityPropagation', affinity_propagation),
        ('MeanShift', ms),
        ('SpectralClustering', spectral),
        ('Ward', ward),
        ('AgglomerativeClustering', average_linkage),
        ('DBSCAN', dbscan),
        ('Birch', birch),
        ('GaussianMixture', gmm)
    )

    for name, algorithm in clustering_algorithms:
        t0 = time.time()

        # catch warnings related to kneighbors_graph
        with warnings.catch_warnings():
            warnings.filterwarnings(
                "ignore",
                message="the number of connected components of the " +
                "connectivity matrix is [0-9]{1,2}" +
                " > 1. Completing it to avoid stopping the tree early.",
                category=UserWarning)
            warnings.filterwarnings(
                "ignore",
                message="Graph is not fully connected, spectral embedding" +
                " may not work as expected.",
                category=UserWarning)
            algorithm.fit(X)

        t1 = time.time()
        if hasattr(algorithm, 'labels_'):
            y_pred = algorithm.labels_.astype(np.int)
        else:
            y_pred = algorithm.predict(X)

        plt.subplot(len(datasets), len(clustering_algorithms), plot_num)
        if i_dataset == 0:
            plt.title(name, size=18)

        colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_pred) + 1))))
        plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])

        plt.xlim(-2.5, 2.5)
        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())
        plt.text(.99, .01, ('%.2fs' % (t1 - t0)).lstrip('0'),
                 transform=plt.gca().transAxes, size=15,
                 horizontalalignment='right')
        plot_num += 1

plt.show()
# Out:
# Automatically created module for IPython interactive environment
